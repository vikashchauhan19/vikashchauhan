# %% [markdown]
# # Data anlysis
# 0.import librariy
# 1.load the data
# 2.check the data and undersatnd
# 3.preprocess the data
# 4.explore the data
# 5. visualize the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/indian_cities.csv', index_col= 0)

# %%
df
# Out:
#             City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1         Mumbai     Maharashtra    12442373          18414288       853
# 2          Delhi           Delhi    11034555          16314838       876
# 3      Bangalore       Karnataka     8443675           8499399       923
# 4      Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5      Ahmedabad         Gujarat     5577940           6352254       898
# ...          ...             ...         ...               ...       ...
# 494      Gangtok          Sikkim      100286            100286       912
# 495        Datia  Madhya Pradesh      100284            100284       900
# 496        Nagda  Madhya Pradesh      100039            100039       947
# 497     Banswara       Rajasthan       99969            101177       960
# 498   Kapurthala          Punjab       98916             98916       839
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# ...

# %%
df2= pd.read_excel('data/data1.xlsx', index_col= 0)

# %%
df2
# Out:
#            Hindi  English  Maths  Science
# Students
# Anchal        45       85     34       34
# Divyanshi     90       34     23       96
# Priya         56       25     14       45
# Anshika       55       55     42       53
# Nikta         45       85     56       65
# Gopal         21       95     99       85
# Ankit         85       45     52       75

# %%
df.head(n=5)
# Out:
#            City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1        Mumbai     Maharashtra    12442373          18414288       853
# 2         Delhi           Delhi    11034555          16314838       876
# 3     Bangalore       Karnataka     8443675           8499399       923
# 4     Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5     Ahmedabad         Gujarat     5577940           6352254       898
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# 4        83.26
# 5        88.29

# %%
df.tail()
# Out:
#             City           State  Population  Metro_Population  Sexratio  \
# Rank
# 494      Gangtok          Sikkim      100286            100286       912
# 495        Datia  Madhya Pradesh      100284            100284       900
# 496        Nagda  Madhya Pradesh      100039            100039       947
# 497     Banswara       Rajasthan       99969            101177       960
# 498   Kapurthala          Punjab       98916             98916       839
#
#       Literacy
# Rank
# 494      89.33
# 495      80.56
# 496      80.71
# 497      85.72
# 498      85.08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498 entries, 1 to 498
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              498 non-null    object
#  1   State             498 non-null    object
#  2   Population        498 non-null    int64
#  3   Metro_Population  498 non-null    int64
#  4   Sexratio          498 non-null    int64
#  5   Literacy          498 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 27.2+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Anchal to Ankit
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Hindi    7 non-null      int64
#  1   English  7 non-null      int64
#  2   Maths    7 non-null      int64
#  3   Science  7 non-null      int64
# dtypes: int64(4)
# memory usage: 280.0+ bytes

# %%
df2.describe()
# Out:
#            Hindi    English      Maths    Science
# count   7.000000   7.000000   7.000000   7.000000
# mean   56.714286  60.571429  45.714286  64.714286
# std    24.018842  27.760026  27.861050  22.231466
# min    21.000000  25.000000  14.000000  34.000000
# 25%    45.000000  39.500000  28.500000  49.000000
# 50%    55.000000  55.000000  42.000000  65.000000
# 75%    70.500000  85.000000  54.000000  80.000000
# max    90.000000  95.000000  99.000000  96.000000

# %%
df.describe()
# Out:
#          Population  Metro_Population     Sexratio    Literacy
# count  4.980000e+02      4.980000e+02   498.000000  498.000000
# mean   4.498030e+05      5.556033e+05   932.903614   84.261004
# std    1.029319e+06      1.501008e+06    55.392315    6.306394
# min    9.891600e+04      9.891600e+04   709.000000   48.280000
# 25%    1.256420e+05      1.384625e+05   894.250000   80.945000
# 50%    1.841050e+05      2.048060e+05   925.000000   85.180000
# 75%    3.495960e+05      4.103862e+05   975.500000   88.612500
# max    1.244237e+07      1.841429e+07  1093.000000   98.360000

# %%
df.describe(exclude=np.number)
# Out:
#               City          State
# count          498            498
# unique         497             30
# top     Aurangabad  Uttar Pradesh
# freq             2             64

# %%
df.describe(include='all')
# Out:
#               City          State    Population  Metro_Population  \
# count          498            498  4.980000e+02      4.980000e+02
# unique         497             30           NaN               NaN
# top     Aurangabad  Uttar Pradesh           NaN               NaN
# freq             2             64           NaN               NaN
# mean           NaN            NaN  4.498030e+05      5.556033e+05
# std            NaN            NaN  1.029319e+06      1.501008e+06
# min            NaN            NaN  9.891600e+04      9.891600e+04
# 25%            NaN            NaN  1.256420e+05      1.384625e+05
# 50%            NaN            NaN  1.841050e+05      2.048060e+05
# 75%            NaN            NaN  3.495960e+05      4.103862e+05
# max            NaN            NaN  1.244237e+07      1.841429e+07
#
#            Sexratio    Literacy
# count    498.000000  498.000000
# unique          NaN         NaN
# top             NaN         NaN
# freq            NaN         NaN
# ...

# %%
df.isnull().sum()
# Out:
# City                0
# State               0
# Population          0
# Metro_Population    0
# Sexratio            0
# Literacy            0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Hindi', 'English', 'Maths', 'Science'], dtype='object')

# %%
df2['Total']= df2['English']+ df2['Hindi']+ df2['Maths'] + df2['Science']

# %%
df2
# Out:
#            Hindi  English  Maths  Science  Total
# Students
# Anchal        45       85     34       34    198
# Divyanshi     90       34     23       96    243
# Priya         56       25     14       45    140
# Anshika       55       55     42       53    205
# Nikta         45       85     56       65    251
# Gopal         21       95     99       85    300
# Ankit         85       45     52       75    257

# %%
df2['Total'].plot(kind= 'bar', figsize=(15, 5))
# Out:
# <AxesSubplot: xlabel='Students'>

# %%
df3 = pd.read_csv('data/API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_4701072.csv', skiprows= 4)

# %%
df3
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code  1960      1961      1962      1963       1964  \
# ...

# %% [markdown]
# ### dataframe reading and selecting aubsets of data
# -row wise selction
#   -df.loc[]
#   -df.iloc[]
#   -df.head[]
#   -df.tail[]
#   -df.query[]
# - column wise selction
#   -df['column_name']
#   - df[['column_name1,'column_name2']]

# %%
df
# Out:
#             City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1         Mumbai     Maharashtra    12442373          18414288       853
# 2          Delhi           Delhi    11034555          16314838       876
# 3      Bangalore       Karnataka     8443675           8499399       923
# 4      Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5      Ahmedabad         Gujarat     5577940           6352254       898
# ...          ...             ...         ...               ...       ...
# 494      Gangtok          Sikkim      100286            100286       912
# 495        Datia  Madhya Pradesh      100284            100284       900
# 496        Nagda  Madhya Pradesh      100039            100039       947
# 497     Banswara       Rajasthan       99969            101177       960
# 498   Kapurthala          Punjab       98916             98916       839
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# ...

# %%
df.loc[2] # specific row , as a series
# Out:
# City                   Delhi
# State                  Delhi
# Population          11034555
# Metro_Population    16314838
# Sexratio                 876
# Literacy               87.59
# Name: 2, dtype: object

# %%
df[100:120] # multiple rows, as a dataframe
# Out:
#                    City           State  Population  Metro_Population  \
# Rank
# 101            Tiruppur      Tamil Nadu      444352            962982
# 102          Davanagere       Karnataka      434971            434971
# 103           Kozhikode          Kerala      431560           2030519
# 104             Kurnool  Andhra Pradesh      430214            478124
# 105               Akola     Maharashtra      425817            425817
# 106     Rajpur Sonarpur     West Bengal      424368            424368
# 107        Bokaro Steel       Jharkhand      414820            563417
# 108             Bellary       Karnataka      410445            410445
# 109             Patiala          Punjab      406192            445196
# 110       South Dum Dum     West Bengal      403316            403316
# 111   Rajarhat Gopalpur     West Bengal      402844            402844
# 112           Bhagalpur           Bihar      400146            410210
# ...

# %%
df.loc[[51, 101 ,201, 301]] # multiple rows in a list style
# Out:
#             City          State  Population  Metro_Population  Sexratio  \
# Rank
# 51      Bareilly  Uttar Pradesh      903668            979933       895
# 101     Tiruppur     Tamil Nadu      444352            962982       955
# 201     Uluberia    West Bengal      222240            222240       951
# 301   Dallo Pura          Delhi      154791            154791       905
#
#       Literacy
# Rank
# 51       68.25
# 101      87.81
# 201      80.03
# 301      83.15

# %%
df.loc[[51, 101, 201, 301,401], ['City','Population']] # same as above
# Out:
#             City  Population
# Rank
# 51      Bareilly      903668
# 101     Tiruppur      444352
# 201     Uluberia      222240
# 301   Dallo Pura      154791
# 401    Darjiling      118805

# %%
df.iloc[:5]
# Out:
#            City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1        Mumbai     Maharashtra    12442373          18414288       853
# 2         Delhi           Delhi    11034555          16314838       876
# 3     Bangalore       Karnataka     8443675           8499399       923
# 4     Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5     Ahmedabad         Gujarat     5577940           6352254       898
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# 4        83.26
# 5        88.29

# %%
df2.iloc[:5]
# Out:
#            Hindi  English  Maths  Science  Total
# Students
# Anchal        45       85     34       34    198
# Divyanshi     90       34     23       96    243
# Priya         56       25     14       45    140
# Anshika       55       55     42       53    205
# Nikta         45       85     56       65    251

# %%
df3.iloc[10:11]
# Out:
#    Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 10      Armenia          ARM  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#     1961  1962  1963  1964  1965  ...  2013  2014  2015  2016  2017  2018  \
# 10   NaN   NaN   NaN   NaN   NaN  ...   3.3   3.6   3.2   0.2   7.5   5.2
#
#     2019  2020  2021  Unnamed: 66
# 10   7.6  -7.4   5.7          NaN
#
# [1 rows x 67 columns]

# %%
df2.iloc[:-2]
# Out:
#            Hindi  English  Maths  Science  Total
# Students
# Anchal        45       85     34       34    198
# Divyanshi     90       34     23       96    243
# Priya         56       25     14       45    140
# Anshika       55       55     42       53    205
# Nikta         45       85     56       65    251

# %%
df2.iloc[-1:]
# Out:
#           Hindi  English  Maths  Science  Total
# Students
# Ankit        85       45     52       75    257

# %%
df2['Hindi']
# Out:
# Students
# Anchal       45
# Divyanshi    90
# Priya        56
# Anshika      55
# Nikta        45
# Gopal        21
# Ankit        85
# Name: Hindi, dtype: int64

# %%
cols= ['State','Literacy','Population']
df[cols]
# Out:
#                State  Literacy  Population
# Rank
# 1        Maharashtra     89.73    12442373
# 2              Delhi     87.59    11034555
# 3          Karnataka     88.71     8443675
# 4     Andhra Pradesh     83.26     6731790
# 5            Gujarat     88.29     5577940
# ...              ...       ...         ...
# 494           Sikkim     89.33      100286
# 495   Madhya Pradesh     80.56      100284
# 496   Madhya Pradesh     80.71      100039
# 497        Rajasthan     85.72       99969
# 498           Punjab     85.08       98916
#
# [498 rows x 3 columns]

# %%
df2['Students']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Students'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2.columns
# Out:
# Index(['Hindi', 'English', 'Maths', 'Science', 'Total'], dtype='object')
