# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 'plt.show()' should be only written at the end of your graph code .it is not necessary to write it after every graph. You can aslo use 'plt.show()' to display multiple graphs at once.

# %% [markdown]
# A simple graph with  sine wave and cosin wave

# %%
t = np.linspace(0, 10, 100)
fig = plt.figure( figsize=(20,5))
plt.plot( t, np.sin(t), 'r--', label= 'sin(t)')
plt.plot( t, np.cos(t), 'b-*', label= 'cos(t)')
plt.legend()
plt.show()

# %% [markdown]
# a figure object is the outermost container for a Matplotlib plot. The figure object contain multiple Axes objects.So, the figure is the  final graphics that may contain one or more Axes.The Axes represent an individual plot.

# %%
fig, ax = plt.subplots(nrows = 1, ncols= 2, figsize=(20, 6))
ax[0].plot(t, np.sin(t), 'r--', label= 'sine wave of t')
ax[1].plot(t, np.cos(t), 'b-*', label= 'cosine wave of t')
ax[0].legend()
ax[1].legend()
plt.show()

# %%
fig, ax = plt.subplots(nrows = 2, ncols= 1, figsize=(20, 6))
ax[0].plot(t, np.sin(t), 'r--', label= 'sine wave of t')
ax[1].plot(t, np.cos(t), 'b-*', label= 'cosine wave of t')
ax[0].legend()
ax[1].legend()
plt.show()

# %%
x = np.linspace(0,10, 100)
plt.plot(x, np.sin(x), 'g-', label= 'sine wave of t')
plt.xlabel('x values' , fontsize= 14, fontdict={'color': 'green'})
plt.ylabel('y values' , fontsize= 14, fontdict={'color': 'green'})
plt.title('sine wave' , fontsize= 16, fontdict={'color': 'green', 'weight': 'bold',})
plt.text(4, .5, 'Y= sin(x)', fontsize= 10, fontdict={'color':'red',})
plt.text(1, .25,'crest', fontsize= 10, fontdict={'color': 'red',})
plt.text(4, -.5, 'trough', fontsize= 10, fontdict={'color': 'red',})
#annotate
plt.annotate('local max', xy=(1.6, 1), xytext=(np.pi/2, 1.4), arrowprops={'facecolor': 'black', 'shrink': 0.05})
plt.show()

# %%
# change the background color
fig = plt.figure(figsize=(20,6), facecolor='lightblue')
x = np.linspace(0, 10, 100)
plt.plot(x,np.sin(x), 'b', label='sin wave of t')
#change axes background color
ax= plt.gca() # get the current graph axes
ax.set_facecolor('#8943ff')

# %% [markdown]
# types of graphs
# 1.line
# 2.scatter
# 3.pie
# 4.bar
# 5.histogram
# 6.boxplot
# 7.stem
# 8.hexbin

# %%
# scatter plot
x = np.random.randn(100)
y = np.random.randn(100)
plt.scatter(x, y, marker='o', color='green')
plt.show()

# %%
x = np.random.randn(100)
y = np.random.randn(100)
size = np.random.randn(100)*100
plt.scatter(x, y, marker='o', color='green', s=size)
plt.show()
# Out:
# c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\matplotlib\collections.py:967: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
fig = plt.figure(figsize=(20,6))
x = np.random.randn(100)
y = np.random.randn(100)
size = np.random.randn(10,100)
plt.scatter(x, y, marker='o', s=size, c=size, alpha=.5, edgecolors='black', cmap='viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\digipython13sep\data_analysis\visualization.ipynb Cell 13 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/digipython13sep/data_analysis/visualization.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> y = np.random.randn(100)
#       <a href='vscode-notebook-cell:/d%3A/digipython13sep/data_analysis/visualization.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> size = np.random.randn(10,100)
# ----> <a href='vscode-notebook-cell:/d%3A/digipython13sep/data_analysis/visualization.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> plt.scatter(x, y, marker='o', s=size, c=size, alpha=.5, edgecolors='black', cmap='viridis')
#       <a href='vscode-notebook-cell:/d%3A/digipython13sep/data_analysis/visualization.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> plt.show()
#
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\matplotlib\pyplot.py:2790, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2785 @_copy_docstring_and_deprecators(Axes.scatter)
#    2786 def scatter(
#    2787         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2788         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2789         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2790     __ret = gca().scatter(
#    2791         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2792         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2793         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2794         **({"data": data} if data is not None else {}), **kwargs)
#    2795     sci(__ret)
#    2796     return __ret
#
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\matplotlib\axes\_axes.py:4529, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4525 s = np.ma.ravel(s)
#    4526 if (len(s) not in (1, x.size) or
#    4527         (not np.issubdtype(s.dtype, np.floating) and
#    4528          not np.issubdtype(s.dtype, np.integer))):
# -> 4529     raise ValueError(
#    4530         "s must be a scalar, "
#    4531         "or float array-like with the same size as x and y")
#    4533 # get the original edgecolor the user passed before we normalize
#    4534 orig_edgecolor = edgecolors
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y

# %%
gender_count = np.array([120,45])
plt.pie(gender_count)
plt.show()

# %%
gender_count = np.array([120,45])
gender_labels = np.array(['Female, Male'])
props= {'color':'white','weight':'bold', 'fontsize':14}
plt.pie(gender_count, labels=gender_labels, textprops=props)#text prop
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\digipython13sep\data_analysis\visualization.ipynb Cell 15 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/digipython13sep/data_analysis/visualization.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> gender_labels = np.array(['Female, Male'])
#       <a href='vscode-notebook-cell:/d%3A/digipython13sep/data_analysis/visualization.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> props= {'color':'white','weight':'bold', 'fontsize':14}
# ----> <a href='vscode-notebook-cell:/d%3A/digipython13sep/data_analysis/visualization.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a> plt.pie(gender_count, labels=gender_labels, textprops=props)#text prop
#       <a href='vscode-notebook-cell:/d%3A/digipython13sep/data_analysis/visualization.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a> plt.show()
#
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\matplotlib\pyplot.py:2727, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2720 @_copy_docstring_and_deprecators(Axes.pie)
#    2721 def pie(
#    2722         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2725         textprops=None, center=(0, 0), frame=False,
#    2726         rotatelabels=False, *, normalize=True, data=None):
# -> 2727     return gca().pie(
#    2728         x, explode=explode, labels=labels, colors=colors,
#    2729         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2730         labeldistance=labeldistance, startangle=startangle,
#    2731         radius=radius, counterclock=counterclock,
#    2732         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2733         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2734         **({"data": data} if data is not None else {}))
#
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File c:\Users\J.A.R.V.I.S\miniconda3\lib\site-packages\matplotlib\axes\_axes.py:3170, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3168     explode = [0] * len(x)
#    3169 if len(x) != len(labels):
# -> 3170     raise ValueError("'label' must be of length 'x'")
#    3171 if len(x) != len(explode):
#    3172     raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'

# %%
# visualization
# stem plot
fig= plt.figure(figsize=(20,6))
x= np.linspace(0, 10, 50)
y= np.sin(x)
plt.stem(x, y, linefmt='r:', markerfmt='r*',basefmt='g')
plt.show()

# %%
#hexbin plot
fig = plt.figure(figsize=(8,6))
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.hexbin(x, y, gridsize= 25, cmap='viridis_r')
plt.colorbar()
plt.show()

# %%
# bar plot
sales= np.array([100,200,300,400,500,420,300,500,600])
months = np.array(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep'])
plt.bar(x = months, height=sales)
plt.show()

# %%
# bar chart with text
plt.bar(x= months,height=sales)
for i in range(len(sales)):
    plt.text(x= i,y=10, s= sales[i], ha='center', fontdict={'color':'black'})
plt.show()

# %%
plt.barh(y= months, width=sales)
plt.show()

# %%
plt.bar(x = months, height=sales, color= 'green', edgecolor= 'black', alpha= 1)
# Out:
# <BarContainer object of 9 artists>

# %%
colors = ['red','green','blue','yellow','orange','purple','brown','pink','gray']
plt.bar(x=months,height=sales,color= colors,edgecolor= 'black', alpha= .5)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.bar(x=months,height=sales,color= colors,edgecolor= 'black', alpha= .5, hatch='/')
# Out:
# <BarContainer object of 9 artists>

# %%
# box plot
fig= plt.figure(figsize=(20,6))
x = np.random.randint(1,10000, (100,3))
plt.boxplot(x, meanline=True, showmeans=True, showfliers=True, notch=True)
plt.show()

# %%
s1_marks = [95,83,94,95,72]
s2_marks = [45,93,90,65,72]
s3_marks = [75,63,70,55,62]
marks = np.array([s1_marks, s2_marks, s3_marks]).T
marks
# Out:
# array([[95, 45, 75],
#        [83, 93, 63],
#        [94, 90, 70],
#        [95, 65, 55],
#        [72, 72, 62]])

# %%
plt.boxplot(marks, labels=['S1','S2','S3'])
plt.show()
